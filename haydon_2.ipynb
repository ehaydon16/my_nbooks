# %% [markdown]
# # Chapter 2 Assignment

# %% [markdown]
# ## Elizabeth Haydon

# %%
import pandas as pd

# %%
url = "ramen-ratings.csv"
rnr = pd.read_csv(url)

# %%
rnr
# Out:
#                Brand                                            Variety Style  \
# 0          New Touch                          T's Restaurant Tantanmen    Cup
# 1           Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2             Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3            Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4     Ching's Secret                                    Singapore Curry  Pack
# ...              ...                                                ...   ...
# 2572           Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2573         Wai Wai                     Oriental Style Instant Noodles  Pack
# 2574         Wai Wai                                     Tom Yum Shrimp  Pack
# 2575         Wai Wai                               Tom Yum Chili Flavor  Pack
# 2576        Westbrae                                         Miso Ramen  Pack
#
#        Country  Stars
# ...

# %%
rnr.head(5)
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#   Country  Stars
# 0   Japan   3.75
# 1  Taiwan   1.00
# 2     USA   2.25
# 3  Taiwan   2.75
# 4   India   3.75

# %%
rnr.tail(5)
# Out:
#          Brand                                            Variety Style  \
# 2572     Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2573   Wai Wai                     Oriental Style Instant Noodles  Pack
# 2574   Wai Wai                                     Tom Yum Shrimp  Pack
# 2575   Wai Wai                               Tom Yum Chili Flavor  Pack
# 2576  Westbrae                                         Miso Ramen  Pack
#
#        Country  Stars
# 2572   Vietnam    3.5
# 2573  Thailand    1.0
# 2574  Thailand    2.0
# 2575  Thailand    2.0
# 2576       USA    0.5

# %%
rnr.describe()
# Out:
#              Stars
# count  2577.000000
# mean      3.654676
# std       1.015331
# min       0.000000
# 25%       3.250000
# 50%       3.750000
# 75%       4.250000
# max       5.000000

# %%
rnr.nunique()
# Out:
# Brand       355
# Variety    2410
# Style         7
# Country      38
# Stars        42
# dtype: int64

# %%
rnr.query('Country==Vietnam')

# %% [markdown]
# No matter what I do, when using the query function I get an error. I have followed the exact steps shown in the book AND the exact steps shown in the ch02 examples. Nothing works. I genuinly don't know what I'm doing wrong. I am using the same exact query function as in the examples but I still get errors. I have tried reducing the code to simply import panda, read csv, displaying the data, and then query. This works for ch02 mortality_data, but not for rnr. Literally the only thing different is mortality_data is reading from a url and rnr is reading from a file. I could try uploading it to github but I feel that shouldn't be the answer.

# %%
rnr[['Brand','Style']]
# Out:
#                Brand Style
# 0          New Touch   Cup
# 1           Just Way  Pack
# 2             Nissin   Cup
# 3            Wei Lih  Pack
# 4     Ching's Secret  Pack
# ...              ...   ...
# 2572           Vifon  Bowl
# 2573         Wai Wai  Pack
# 2574         Wai Wai  Pack
# 2575         Wai Wai  Pack
# 2576        Westbrae  Pack
#
# [2577 rows x 2 columns]

# %%
rnr['Country']
# Out:
# 0          Japan
# 1         Taiwan
# 2            USA
# 3         Taiwan
# 4          India
#           ...
# 2572     Vietnam
# 2573    Thailand
# 2574    Thailand
# 2575    Thailand
# 2576         USA
# Name: Country, Length: 2577, dtype: object

# %%
rnr.sort_values('Stars',ascending=False)
# Out:
#                Brand                                            Variety Style  \
# 1585     Prima Taste                            Singapore Laksa La Mian  Pack
# 446         Maruchan  Instant Lunch Chipotle Chicken Flavor Ramen No...   Cup
# 484         Nongshim          Champong Noodle Soup Spicy Seafood Flavor  Pack
# 483           Nissin                              Straits Kitchen Laksa  Pack
# 1613          Nissin                 Raoh Backfat Rich Soy Sauce Flavor  Bowl
# ...              ...                                                ...   ...
# 522             Koyo                 Garlic Pepper Reduced Sodium Ramen  Pack
# 561    Samyang Foods                            Honey & Cheese Big Bowl  Bowl
# 950            Azami                                Kimchee Noodle Soup   Cup
# 2079  Hsin Tung Yang                     Tiny Noodle With Oyster Flavor  Pack
# 52     Uni-President                                    Mushroom Flavor  Pack
#
#           Country  Stars
# ...

# %%
rnr.Country.replace(
    to_replace = ['USA'],
    value = ['United States'],
    inplace=True)

# %%
rnr.head(5)
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#          Country  Stars
# 0          Japan   3.75
# 1         Taiwan   1.00
# 2  United States   2.25
# 3         Taiwan   2.75
# 4          India   3.75

# %%
n = len(pd.unique(rnr['Country']))
print(n)
# Out:
# 37

# %%
rnr.sort_values(['Country','Stars'])
# Out:
#                Brand                                            Variety Style  \
# 359        Fantastic                       Noodles Crispy Bacon Flavour   Cup
# 549         Singa-Me                       Instant Noodles Beef Flavour   Cup
# 567          Trident                     2 Minute Laksa Flavour Noodles  Pack
# 451           Suimin          Noodles With Chicken & Sweet Corn Flavour   Cup
# 390         Singa-Me                    Instant Noodles Chicken Flavour   Cup
# ...              ...                                                ...   ...
# 2181    Vina Acecook                  Bestcook Hot spicy Tom Yum Shrimp  Bowl
# 2196  Saigon Ve Wong                Kung Fu Artificial Beef Rice Noodle  Pack
# 2215    Vina Acecook                       Daily Hot & Sour With Shrimp  Pack
# 2130         Ve Wong                                Little Prince Bacon  Pack
# 224            Vifon  Viet Cuisine Bun Rieu Cua Sour Crab Soup Insta...  Bowl
#
#         Country  Stars
# ...

# %%
rnr['MeanCentered'] = \
    rnr.Stars - rnr.Stars.mean()

# %%
rnr.head(5)
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#          Country  Stars  MeanCentered
# 0          Japan   3.75      0.095324
# 1         Taiwan   1.00     -2.654676
# 2  United States   2.25     -1.404676
# 3         Taiwan   2.75     -0.904676
# 4          India   3.75      0.095324

# %% [markdown]
# I cannot figure out the rest, I apologize. I cannot find in the examples how to average the star rating via country, I think it might have to do with the error I saw above, where I cannot use the query function. Once I am able to solve said error, I will try again.
